# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/new_documents.csv')

# %%
print(df.shape, '\n')
df.head()
# Out:
# (0, 10)
# Empty DataFrame
# Columns: [title, text, url, authors, timestamp, tags, text_length, title_length, num_tags, num_authors]
# Index: []

# %%
# df.iloc[0:0].to_csv('../Dataset/new_documents.csv', index=False)

# %%
title = 'xxxxxxxxxxx'
text = 'lksdajf jlksajf s jlasj f;llj kjsdal;jf sdljkk sssssssssssssssssssssssssss'
url = 'No url'
authors = "['Abdul Rehman', 'Tahir']"
timestamp = '2020-07-01 00:00:00'
tags = "['Test', 'Sample']"

text_length = len(text.split())
title_length = len(title.split())
num_tags = len(eval(tags))
num_authors = len(eval(authors))

print(f'Text Length: {text_length}\nTitle Length: {title_length}\nNumber of Tags: {num_tags}\nNumber of Authors: {num_authors}')
# Out:
# Text Length: 8
# Title Length: 1
# Number of Tags: 2
# Number of Authors: 2

# %%
data = {
    'title': [title],
    'text': [text],
    'url': [url],
    'authors': [authors],
    'timestamp': [timestamp],
    'tags': [tags],
    'text_length': [text_length],
    'title_length': [title_length],
    'num_tags': [num_tags],
    'num_authors': [num_authors]
}

# %%
df_new_doc = pd.DataFrame(data)
df = pd.concat([df, df_new_doc], ignore_index=True)

# %%
df.head()
# Out:
#          title                                               text     url  \
# 0  xxxxxxxxxxx  lksdajf jlksajf s jlasj f;llj kjsdal;jf sdljkk...  No url
#
#                      authors            timestamp                tags  \
# 0  ['Abdul Rehman', 'Tahir']  2020-07-01 00:00:00  ['Test', 'Sample']
#
#   text_length title_length num_tags num_authors
# 0           8            1        2           2

# %%
# Saving this in the same file
df.to_csv('../datasets/new_documents.csv', index=False)
print('New Document Added Successfully!')
# Out:
# New Document Added Successfully!

# %% [markdown]
# <hr>
